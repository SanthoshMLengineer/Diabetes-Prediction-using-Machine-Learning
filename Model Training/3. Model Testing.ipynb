# %%
import numpy as  np
import pandas as pd

dict_test_data = {"Pregnancies" : 1,
                  "Glucose" : 117,
                  "BloodPressure" : 88,
                  "SkinThickness" : 24,
                  "Insulin" : 145,
                  "BMI" : 34.5,
                  "DiabetesPedigreeFunction" : 0.403,
                  "Age" : 40
}

data_input = pd.DataFrame(dict_test_data, index = [0])

data_input
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1      117             88             24      145  34.5
#
#    DiabetesPedigreeFunction  Age
# 0                     0.403   40

# %%
data_input.shape
# Out:
# (1, 8)

# %%
import sklearn

sklearn.__version__
# Out:
# '1.0.2'

# %%
data_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               1 non-null      int64
#  1   Glucose                   1 non-null      int64
#  2   BloodPressure             1 non-null      int64
#  3   SkinThickness             1 non-null      int64
#  4   Insulin                   1 non-null      int64
#  5   BMI                       1 non-null      float64
#  6   DiabetesPedigreeFunction  1 non-null      float64
#  7   Age                       1 non-null      int64
# dtypes: float64(2), int64(6)
# memory usage: 72.0 bytes

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pickle

folder_path = "/content/drive/My Drive/Selling Project/\
Real Time Projects/Diabetic Prediction/Data Files/"s
algo_name = "Random_forest.pkl"

filepath = folder_path + algo_name

with open(filepath, "rb") as file_pointer:
    model = pickle.load(file_pointer)

model
# Out:
# RandomForestClassifier()

# %%
model.predict(data_input)
# Out:
# array([1])

# %%
model.predict_proba(data_input)
# Out:
# array([[0.02, 0.98]])
